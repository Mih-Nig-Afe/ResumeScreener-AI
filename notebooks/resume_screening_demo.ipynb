# %% [markdown]
# # Resume Screening Demo
# Machine Learning Task 3 (Future Interns): rank candidates against a job description using NLP.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / 'src').exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

import pandas as pd
from src.pipeline import ResumeScreeningPipeline

# %%
pipeline = ResumeScreeningPipeline()
artifacts = pipeline.run(
    resumes_path=str(PROJECT_ROOT / 'data/raw/resumes_sample.csv'),
    job_description_path=str(PROJECT_ROOT / 'data/raw/job_description_data_scientist.txt'),
    role='data_scientist',
    output_dir=str(PROJECT_ROOT / 'data/processed')
)
artifacts
# Out:
# {'ranking': '/Users/fed/Documents/GitHub/FUTURE_ML_03/data/processed/candidate_ranking.csv',
#  'summary': '/Users/fed/Documents/GitHub/FUTURE_ML_03/data/processed/screening_summary.json'}

# %%
pd.read_csv(PROJECT_ROOT / 'data/processed/candidate_ranking.csv').head(10)
# Out:
#    rank candidate_id candidate_name  final_fit_score  similarity_score  \
# 0     1     CAND_001     Alice Mulu            46.15             22.30
# 1     2     CAND_008    Hanna Ayele            43.55             22.10
# 2     3     CAND_006  Frehiwot Alem            40.20             20.39
# 3     4     CAND_002  Brian Tadesse            22.01              9.02
# 4     5     CAND_004     Dina Gebre            19.89              9.78
# 5     6     CAND_003   Caleb Bekele            17.18              4.36
# 6     7     CAND_007  Girma Teshome            14.52              4.03
# 7     8     CAND_005    Elias Worku            14.39              8.78
#
#    required_skill_score  important_skill_score  \
# 0                 85.71                  33.33
# 1                 85.71                  16.67
# 2                 57.14                  66.67
# 3                 28.57                  50.00
# 4                 28.57                  33.33
# ...
